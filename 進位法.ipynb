# %% [markdown]
# #1.

# %%
int("0b1001001",2)
# Out:
# 73

# %%
oct(73)
# Out:
# '0o111'

# %%
hex(73)
# Out:
# '0x49'

# %%
bin(73)
# Out:
# '0b1001001'

# %% [markdown]
# #2.

# %%
bin(0o65416)
# Out:
# '0b110101100001110'

# %%
hex(0o65416)
# Out:
# '0x6b0e'

# %% [markdown]
# #3.

# %%
min(12,81,93,27)
# Out:
# 12

# %%
max(12,81,93,27)
# Out:
# 93

# %% [markdown]
# #4.

# %%
s1='Have a nice day'
print(s1[7:11])
# Out:
# nice

# %%
s1='Have a nice day'
print('day' in s1)
# Out:
# True

# %%
s1[-1]
# Out:
# 'y'

# %%
str1='Have a nice day'
max(str1)
# Out:
# 'y'
