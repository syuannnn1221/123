# %% [markdown]
# 1.

# %%
5>2 and 3<3
# Out:
# False

# %%
2!=6 or 3==5
# Out:
# True

# %%
6>3 or 8>4 or 1==2
# Out:
# True

# %% [markdown]
# 2.

# %%
type(321+789)
# Out:
# int

# %%
type(True+False)
# Out:
# int

# %%
type(8+2.5)
# Out:
# float

# %%
type(str(4)+"710")
# Out:
# str

# %%
type(int("3")+3)
# Out:
# int

# %% [markdown]
# 3.

# %%
a=int(input("請輸入一個十進位數字:"))
print(bin(a))
print(oct(a))
print(hex(a))
# Out:
# 請輸入一個十進位數字:31
# 0b11111
# 0o37
# 0x1f

# %% [markdown]
# 4.

# %%
import math
a=math.sqrt((3-0)**2+(5-0)**2)
b=math.sqrt((2-0)**2+(7-0)**2)
c=math.sqrt((3-0)**2+(8-0)**2)
print("(3,5)到(0,0)的距離是",end=""); print("a=%4.2f"%a)
print("(2,7)到(0,0)的距離是",end=""); print("b=%4.2f"%b)
print("(3,8)到(0,0)的距離是",end=""); print("c=%4.2f"%c)
# Out:
# (3,5)到(0,0)的距離是a=5.83
# (2,7)到(0,0)的距離是b=7.28
# (3,8)到(0,0)的距離是c=8.54

# %% [markdown]
# 5.

# %%
a = "(b - 32) * 5//9"
b=int(input()) ; eval(a)
# Out:
# 100
# 37
