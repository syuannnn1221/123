# %% [markdown]
# # 1.試說明下列的變數各是屬於哪一種型別。
# (a)’2+3’(b)True(c)6500 (d)2.30  (e)False(f)5.(g)6e3(h)7.5e-3 (i)0x12(j)0o712(k)6
# +1j(l)1314(m)’python’

# %%
# 答：(a)str (b)bool (c)int (d)float (e)bool (f)float (g)inf (h)inf (i)int (j)int (k)複數complex (l)int (m)str

# %% [markdown]
# # 2.試輸入下面不同進位的數字，並寫出它們的十進位。
# (1)16進位的數字 a0ff、121ab、acd123
# (2)8進位的數字7231、754、567
# (3)2進位的數字 11001010、1001001、110101000100010110

# %% [markdown]
# 1

# %%
int("a0ff",16)
# Out:
# 41215

# %%
int("121ab",16)
# Out:
# 74155

# %%
int("acd123",16)
# Out:
# 11325731

# %% [markdown]
# 2

# %%
int("7231",8)
# Out:
# 3737

# %%
int("754",8)
# Out:
# 492

# %%
int("567",8)
# Out:
# 375

# %% [markdown]
# 3

# %%
int("11001010",2)
# Out:
# 202

# %%
int("1001001",2)
# Out:
# 73

# %%
int("110101000100010110",2)
# Out:
# 217366

# %% [markdown]
# # 3.設Python 有一行程式碼為num=12；num=12+7.2試問執行完這行程式碼之後，num的型別為何?

# %%
num=12
num=12+7.2
type(num)
# Out:
# float

# %% [markdown]
# # 4.下列的變數中，有哪些比較適合用來當成常數的名稱?
# (a) MAX_NUM(b)True(c)day(d)ID(e)Sky

# %%
#a,c,d,e

# %% [markdown]
# # 5.試計算2**120的值

# %%
2**120
# Out:
# 1329227995784915872903807060280344576

# %% [markdown]
# # 6.試求128/39的餘數

# %%
# %=餘數
128%39
# Out:
# 11

# %% [markdown]
# # 7.如果執行’kitty’<’kitten’，我們會得到False。試說明為什麼會得到這個結果?

# %%
print(ord("y"),ord("e"))
#121沒有小於101，所以是False
# Out:
# 121 101

# %%
print("kitty"<"kitten")
# Out:
# False

# %% [markdown]
# # 8.試判別下列各式的運算結果，並利用Python驗證判別結果是否正確。
# (1) 8<3 and 7==9 and 7>4(2) 2>8 or 7<=8 and 7>2(3) False and ‘kitty’ or True

# %%
8<3 and 7==9 and 7>4
# Out:
# False

# %%
2>8 or 7<=8 and 7>2
# Out:
# True

# %%
False and "kitty" or True
# Out:
# True

# %% [markdown]
# # 9.下列各小題運算完之後，變數x的值為何?
# (1) x=5；x+=2(2) x=7；x+=2(3) x=3；x**=4

# %%
x=5
x=x+2
print(x)
# Out:
# 7

# %%
x=7
x=x+2
print(x)
# Out:
# 9

# %%
x=3
x=x**4
print(x)
# Out:
# 81

# %% [markdown]
# # 10.設x=12，y=8，試推導下面各式，並以Python驗證你得出的結果:
# (a)x&y(b)x|y(c)~x(d)x^y (e)x>>2(f)x<<2(g)~y(h)y>>2(i)y<<2

# %% [markdown]
# a

# %%
x=12
y=8
x&y
# 12(1100)
# 8(1000)
# Out:
# 8

# %% [markdown]
# b

# %%
x=12
y=8
x|y
# Out:
# 12

# %% [markdown]
# c

# %%
x=12
y=8
~x
# Out:
# -13

# %% [markdown]
# d

# %%
x=12
y=8
x^y
# Out:
# 4

# %% [markdown]
# e

# %%
x=12
y=8
x>>2
# Out:
# 3

# %% [markdown]
# f

# %%
x=12
y=8
x<<y
# Out:
# 3072

# %% [markdown]
# g

# %%
x=12
y=8
~y
# Out:
# -9

# %% [markdown]
# h

# %%
x=12
y=8
y>>2
# Out:
# 2

# %% [markdown]
# i

# %%
x=12
y=8
y<<2
# Out:
# 32

# %% [markdown]
# # 11.試以紙筆推導下面各式，並以Python驗證你得出的結果:
# (1)8<3 and 7==9 and 7>4 答：(2) 2>8 or 7<=8 and 7>2答：(3)False and ‘kitty’ or True

# %%
8<3 and 7==9 and 7>4
# Out:
# False

# %%
2>8 or 7<=8 and 7>2
# Out:
# True

# %%
False and "kitty" or True
# Out:
# True

# %% [markdown]
# # 12.如果在Python裡執行下面兩行敘述，你會得到不同的錯誤訊息:
# True + not ‘piggy’
# not ‘piggy’ + True
# 試說明這兩個敘述錯誤的原因，並且嘗試加上括號讓它們可以正確的執行

# %%
True + (not 'piggy')
(not 'piggy') + True
# Out:
# 1

# %% [markdown]
# # 13.下面的敘述都會牽扯到型別的轉換，試說明它們是屬於隱式還是顯式轉換
# (1)2+True(2)6+int(17.4)(3)21+6.5(4)str(2)+’piggy

# %%
#(1)2+True    隱式
#(2)6+int     顯式
#(3)21+6.5     隱式
#(4)str(2)+’piggy 顯式

# %% [markdown]
# # 14.試對下面表達成字串的運算試求值
# (1)’66+18’(2)’6**2+3*(7-1)’(3)”int(‘2020’)”

# %% [markdown]
# 1

# %%
expr='66+18'
eval(expr)
# Out:
# 84

# %% [markdown]
# 2

# %%
expr='6*2+3*(7-1)'
eval(expr)
# Out:
# 30

# %% [markdown]
# 3

# %%
expr="int('2020')"
eval(expr)
# Out:
# 2020

# %% [markdown]
# # 15.試將10進位的整數1024分別轉為2進位、8進位和16進位

# %%
bin(1024)  #2進位
# Out:
# '0b10000000000'

# %%
oct(1024)  #8進位
# Out:
# '0o2000'

# %%
hex(1024)  #16進位
# Out:
# '0x400'

# %% [markdown]
# # 16.試將八進位的數字0o65416分別轉成2進位、10進位、16進位

# %%
bin(int("0o65416",8)) #轉2進位
# Out:
# '0b110101100001110'

# %%
int("0o65416",8)  #轉10進位
# Out:
# 27406

# %%
hex(int("0o65416",8))  #轉16進位
# Out:
# '0x6b0e'

# %% [markdown]
# # 17.試將2進位的數字0b1001001分別轉成8進位、10進位、16進位

# %%
oct(int("0b1001001",2))
# Out:
# '0o111'

# %%
int("0b1001001",2)
# Out:
# 73

# %%
hex(int("0b1001001",2))
# Out:
# '0x49'

# %% [markdown]
# # 18.試利用print()函數印出下面的字串
# (1)’Holliday’(2)”You may say I’m a dreamer”(3)A back slash \ sign.(4)’’’\n represents a new line character’’’

# %% [markdown]
# 1

# %%
print("\'Holliday\'")
# Out:
# 'Holliday'

# %% [markdown]
# 2

# %%
print("\"You may say I’m a dreamer\"")
# Out:
# "You may say I’m a dreamer"

# %% [markdown]
# 3

# %%
print("A back slash \\sign.")
# Out:
# A back slash \sign.

# %% [markdown]
# 4

# %%
print("'''\\n represents a new line character'''")
# Out:
# '''\n represents a new line character'''

# %% [markdown]
# # 19.設a=12670,b=12.344，試利用f-字串將變數a與b列印出如下的格式:
# (1)a=  12670, b=12.34(2)a= +12670, b=012.34(3)a=+12,670, b=0012.3(4)a=012,670, b=   +12(5)a={12670}, b=’  12’

# %% [markdown]
# 1

# %%
a=12670
b=12.344
print('a=%5d,b=5.2f'%(a,b))
# Out:
# a=12670,b=12.34

# %% [markdown]
# 2

# %%
a=12670
b=12.344
print('a=+%5d,b=%06.2f'%(a,b))
# Out:
# a=+12670,b=012.34

# %% [markdown]
# 3

# %%
a=12670
b=12.344
(f'a={a},b={b}')
print(f'a={a:+,},b={b:07.1f}')
# Out:
# a=+12,670,b=00012.3

# %% [markdown]
# 4

# %%
a=12670
b=12.344
(f'a={a},b={b}')
print(f'a={a:>07,},b={b:06.1f}')
# Out:
# a=012,670,b=0012.3

# %% [markdown]
# 5

# %%
a=12670
b=12.344

# %% [markdown]
# # 20.試利用input()函數從鍵盤讀入一個數，計算這個數的平方之後，將他列印出來。

# %%
expr=input("輸入一個數:")
eval(expr)**2
# Out:
# 輸入一個數:9
# 81

# %% [markdown]
# # 21.試從鍵盤讀入一個整數，將它轉成2進位之後，將轉換結果列印出來。

# %%
expr=input("輸入一個整數:")
bin(eval(expr))
# Out:
# 輸入一個整數:8
# '0b1000'
